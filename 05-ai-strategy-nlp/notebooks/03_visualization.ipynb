# %% [markdown]
# # 03 Visualization
# Generate figures comparing "Safety/Ethics" vs "Development/Access" term clusters.

# %%
from pathlib import Path
import sys
sys.path.append(str((Path('..')).resolve()))
from src import visualization as viz

RESULTS_DIR = Path('..') / 'results'
FIG_DIR = RESULTS_DIR / 'figures'

# %%
# Example placeholders; replace with outputs from 02_nlp_analysis
north_terms = {'safety': 0.12, 'governance': 0.1, 'ethic': 0.08}
south_terms = {'infrastructure': 0.15, 'access': 0.13, 'development': 0.1}

# %%
fig = viz.plot_cluster_comparison(north_terms, south_terms, title='Normative emphasis')
viz.save_figure(fig, FIG_DIR / 'cluster_comparison.png')

# %%
# Single-term bars if needed
fig2 = viz.plot_term_scores(north_terms, title='Global North term scores')
viz.save_figure(fig2, FIG_DIR / 'north_terms.png')
# Out:
# /home/huan/research-workspace/Research-Portfolio/05-ai-strategy-nlp/src/visualization.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(terms, rotation=rotation, ha="right")
